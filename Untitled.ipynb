# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
num_of_trees = [50,100,150]
Iris_Gini = np.array([36,34,36]) / 45
Iris_Entropy = np.array([33,34,36]) / 45
Iris_Misclassification = np.array([36,39,38]) / 45

# %% [markdown]
# # Hey I just can't go without saying that I noticed you used color triads! And I bet it was by design.

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_axes([0,0,1,1])
num_of_trees = np.array(num_of_trees)
ax.bar(num_of_trees-10, Iris_Misclassification*100, color = 'navy', width = 10)
ax.bar(num_of_trees, Iris_Entropy*100, color='g',width=10)
ax.bar(num_of_trees+10,Iris_Gini*100,color='darkorange',width=10)
ax.set_xticks(num_of_trees)
ax.set_yticks(np.arange(70,90, 2))
ax.set_ylabel("Accuracy (%)", fontsize = 15)
ax.set_xlabel("Number of decision trees", fontsize = 15)
ax.legend(['Misclassification','Entropy','Gini Index'], fontsize = 15)
plt.ylim([70,90])
plt.title("Iris Data Set Accuracy", fontsize = 15)

plt.savefig('out/acc_iris.jpg')

# %%
C = np.array([7455,7455,7455])/9769
B = np.array([7455,7455,7455])/9769
A = np.array([7665,7775,7777])/9769

fig = plt.figure(figsize=(10,5))
ax = fig.add_axes([0,0,1,1])
num_of_trees = np.array(num_of_trees)
ax.bar(num_of_trees-10, A*100, color = 'navy', width = 10)
ax.bar(num_of_trees, B*100, color='g',width=10)
ax.bar(num_of_trees+10,C*100,color='darkorange',width=10)
ax.set_xticks(num_of_trees)
ax.set_yticks(np.arange(75,85, 1))
ax.set_ylabel("Accuracy (%)", fontsize = 15)
ax.set_xlabel("Number of decision trees", fontsize = 15)
ax.legend(['Misclassification','Entropy','Gini Index'], fontsize = 15)
plt.ylim([75,85])
plt.title("Adult Data Set Accuracy", fontsize = 15)

plt.savefig('out/acc_adult.jpg')

# %%
C = np.array([1160,1170,1178])/1200
B = np.array([1181,1170,1178])/1200
A = np.array([1186,1183,1188])/1200

fig = plt.figure(figsize=(10,5))
ax = fig.add_axes([0,0,1,1])
num_of_trees = np.array(num_of_trees)
ax.bar(num_of_trees-10, A*100, color = 'navy', width = 10)
ax.bar(num_of_trees, B*100, color='g',width=10)
ax.bar(num_of_trees+10,C*100,color='darkorange',width=10)
ax.set_xticks(num_of_trees)
ax.set_yticks(np.arange(90,100, 1))
ax.set_ylabel("Accuracy (%)", fontsize = 15)
ax.set_xlabel("Number of decision trees", fontsize = 15)
ax.legend(['Misclassification','Entropy','Gini Index'], fontsize = 15, loc='best')
plt.ylim([90,100])
plt.title("Blobs Data Set Accuracy", fontsize = 15)

plt.savefig('out/acc_blobs.jpg')

# %%
C = np.array([36,38,35])/1200
B = np.array([38,36,36])/1200
A = np.array([38,35,35])/1200

fig = plt.figure(figsize=(10,5))
ax = fig.add_axes([0,0,1,1])
num_of_trees = np.array(num_of_trees)
ax.bar(num_of_trees-10, A*100, color = 'navy', width = 10)
ax.bar(num_of_trees, B*100, color='g',width=10)
ax.bar(num_of_trees+10,C*100,color='darkorange',width=10)
ax.set_xticks(num_of_trees)
ax.set_ylabel("Accuracy (%)", fontsize = 15)
ax.set_xlabel("Number of decision trees", fontsize = 15)
ax.legend(['Misclassification','Entropy','Gini Index'], fontsize = 15)
plt.ylim([0,100])
plt.title("Spirals Data Set Accuracy", fontsize = 15)

plt.savefig('out/acc_spirals1200.jpg')

# %%
C = np.array([196,195,194])/300
B = np.array([177,169,192])/300
A = np.array([194,195,214])/300

fig = plt.figure(figsize=(10,5))
ax = fig.add_axes([0,0,1,1])
num_of_trees = np.array(num_of_trees)
ax.bar(num_of_trees-10, A*100, color = 'navy', width = 10)
ax.bar(num_of_trees, B*100, color='g',width=10)
ax.bar(num_of_trees+10,C*100,color='darkorange',width=10)
ax.set_xticks(num_of_trees)
ax.set_yticks(np.arange(55,75,2))
ax.set_ylabel("Accuracy (%)", fontsize = 15)
ax.set_xlabel("Number of decision trees", fontsize = 15)
ax.legend(['Misclassification','Entropy','Gini Index'], fontsize = 15)
plt.ylim([55,75])
plt.title("Spirals Data Set Accuracy", fontsize = 15)

plt.savefig('out/acc_spirals.jpg')

# %%
C = np.array([[326,432,470],[322,453,468],[345,448,464]])/540
B = np.array([[54,43,50],[43,59,50],[50,47,53]])/540
A = np.array([[328,457,463],[334,431,464],[334,444,461]])/540

fig,axs = plt.subplots(3, figsize=(15,15))
M=[2,4,6]

for i in range(0,len(M)):
    axs[i].bar(num_of_trees-10, A[i]*100, color = 'navy', width = 10)
    axs[i].bar(num_of_trees, B[i]*100, color='g',width=10)
    axs[i].bar(num_of_trees+10,C[i]*100,color='darkorange',width=10)
    axs[i].set_xticks(num_of_trees)
    axs[i].set_title(f"M Value: {M[i]}", fontsize = 15) 
    axs[i].set_ylabel("Accuracy (%)", fontsize = 15)
   
    axs[i].legend(['Misclassification','Entropy','Gini Index'], fontsize = 10)
    
axs[2].set_xlabel("Number of decision trees", fontsize = 15)
plt.suptitle("MNIST Data Set Accuracy For M and Number of Decision Trees", fontsize = 15)

plt.savefig('out/acc_mnist.jpg')

# %%
C = np.array([402,348,368])/519
B = np.array([358,358,358])/519
A = np.array([373,375,360])/519

fig = plt.figure(figsize=(10,5))
ax = fig.add_axes([0,0,1,1])
num_of_trees = np.array(num_of_trees)
ax.bar(num_of_trees-10, A*100, color = 'navy', width = 10)
ax.bar(num_of_trees, B*100, color='g',width=10)
ax.bar(num_of_trees+10,C*100,color='darkorange',width=10)
ax.set_xticks(num_of_trees)
ax.set_yticks(np.arange(60,80,2))
ax.set_ylabel("Accuracy (%)", fontsize = 15)
ax.set_xlabel("Number of decision trees", fontsize = 15)
ax.legend(['Misclassification','Entropy','Gini Index'], fontsize = 15)
plt.ylim([60,80])
plt.title("Car Evaluation Data Set Accuracy", fontsize = 15)

plt.savefig('out/acc_car.jpg')

# %%
C = np.array([[382,369,370],[413,404,417],[418,415,425]])/519
B = np.array([[358,358,358],[358,358,358],[358,358,358]])/519
A = np.array([[367,368,363],[409,363,389],[399,401,375]])/519

fig,axs = plt.subplots(3, figsize=(15,15))
M=[2,4,6]

for i in range(0,len(M)):
    axs[i].bar(num_of_trees-10, A[i]*100, color = 'navy', width = 10)
    axs[i].bar(num_of_trees, B[i]*100, color='g',width=10)
    axs[i].bar(num_of_trees+10,C[i]*100,color='darkorange',width=10)
    axs[i].set_xticks(num_of_trees)
    axs[i].set_yticks(np.arange(65,85,2))
    axs[i].set_title(f"M Value: {M[i]}", fontsize = 15) 
    axs[i].set_ylabel("Accuracy (%)", fontsize = 15)
    axs[i].set_ylim([65,85])
    axs[i].legend(['Misclassification','Entropy','Gini Index'], fontsize = 10, loc='center right')
    
axs[2].set_xlabel("Number of decision trees", fontsize = 15)

plt.suptitle("Car Evaluation Data Set Accuracy For M and Number of Decision Trees", fontsize = 15)

plt.savefig('out/acc_car_m.jpg')
