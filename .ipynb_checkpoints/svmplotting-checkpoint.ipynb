# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
B = np.array([7455,7455,7455])/9769
A = np.array([7665,7775,7777])/9769

fig = plt.figure(figsize=(10,5))
#plt.xticks([0,1,2],["a","b","c"])
ax = fig.add_axes([0,0,1,1])
ax.bar(0, A*100, color = 'navy', width = 5)
ax.bar(20, B*100, color='g',width=5)
#ax.set_xticks([0, 1, 2], ["Innter Product","Polynomial","Gaussian"])
plt.xticks([0,1,2],["a","b","c"])
#ax.set_yticks(np.arange(75,85, 1))
ax.set_ylabel("Accuracy (%)", fontsize = 15)
ax.set_xlabel("Kernel", fontsize = 15)
ax.legend(['Simplified SMO','Extended SMO'], fontsize = 15)
plt.ylim([75,85])
plt.title("Blobs Test Data Set Accuracy", fontsize = 15)
plt.show()
plt.savefig('out/acc_adult.jpg')
