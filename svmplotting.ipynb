# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
A = np.array([1,0.513,0.487])
B = np.array([0.993,0.954,0.993])

fig = plt.figure(figsize=(10,5))
#plt.xticks([0,1,2],["a","b","c"])
ax = fig.add_axes([0,0,1,1])
spaced = np.array([1,7,13])
ax.bar(spaced, A*100, color = 'navy', width = 2)
ax.bar(spaced+2, B*100, color='g',width=2)
#ax.set_xticks([0, 1, 2], ["Innter Product","Polynomial","Gaussian"])
plt.xticks([2,8,14],["Inner Product","Polynomial","Gaussian"], fontsize=12)
#ax.set_yticks(np.arange(75,85, 1))
ax.set_ylabel("Accuracy (%)", fontsize = 15)
ax.set_xlabel("Kernel", fontsize = 15)
ax.legend(['Simplified SMO','Extended SMO'], fontsize = 15)
plt.ylim([40,110])
plt.title("Blobs Test Data Set Accuracy", fontsize = 15)
#plt.show()
plt.savefig('out/svmblob.jpg',bbox_inches='tight', dpi=150)

# %%
A = np.array([0.547,0.53,0.51])
B = np.array([0.53,0.5,0.7])

fig = plt.figure(figsize=(10,5))
#plt.xticks([0,1,2],["a","b","c"])
ax = fig.add_axes([0,0,1,1])
spaced = np.array([1,7,13])
ax.bar(spaced, A*100, color = 'navy', width = 2)
ax.bar(spaced+2, B*100, color='g',width=2)
#ax.set_xticks([0, 1, 2], ["Innter Product","Polynomial","Gaussian"])
plt.xticks([2,8,14],["Inner Product","Polynomial","Gaussian"], fontsize=12)
#ax.set_yticks(np.arange(75,85, 1))
ax.set_ylabel("Accuracy (%)", fontsize = 15)
ax.set_xlabel("Kernel", fontsize = 15)
ax.legend(['Simplified SMO','Extended SMO'], fontsize = 15)
plt.ylim([40,80])
plt.title("Spirals Test Data Set Accuracy", fontsize = 15)
#plt.show()
plt.savefig('out/svmspirals.jpg',bbox_inches='tight', dpi=150)

# %%
A = np.array([0.719,0.71,0.71])
B = np.array([0.552,0.66,0.31])

fig = plt.figure(figsize=(10,5))
#plt.xticks([0,1,2],["a","b","c"])
ax = fig.add_axes([0,0,1,1])
spaced = np.array([1,7,13])
ax.bar(spaced, A*100, color = 'navy', width = 2)
ax.bar(spaced+2, B*100, color='g',width=2)
#ax.set_xticks([0, 1, 2], ["Innter Product","Polynomial","Gaussian"])
plt.xticks([2,8,14],["Inner Product","Polynomial","Gaussian"], fontsize=12)
#ax.set_yticks(np.arange(75,85, 1))
ax.set_ylabel("Accuracy (%)", fontsize = 15)
ax.set_xlabel("Kernel", fontsize = 15)
ax.legend(['Simplified SMO','Extended SMO'], fontsize = 15)
plt.ylim([20,80])
plt.title("Car Eval Test Data Set Accuracy", fontsize = 15)
#plt.show()
plt.savefig('out/svmceval.jpg',bbox_inches='tight', dpi=150)

# %%
A = np.array([0.8,0.2,0.2])
B = np.array([0.589,0,0.8])

fig = plt.figure(figsize=(10,5))
#plt.xticks([0,1,2],["a","b","c"])
ax = fig.add_axes([0,0,1,1])
spaced = np.array([1,7,13])
ax.bar(spaced, A*100, color = 'navy', width = 2)
ax.bar(spaced+2, B*100, color='g',width=2)
#ax.set_xticks([0, 1, 2], ["Innter Product","Polynomial","Gaussian"])
plt.xticks([2,8,14],["Inner Product","Polynomial","Gaussian"], fontsize=12)
#ax.set_yticks(np.arange(75,85, 1))
ax.set_ylabel("Accuracy (%)", fontsize = 15)
ax.set_xlabel("Kernel", fontsize = 15)
ax.legend(['Simplified SMO','Extended SMO'], fontsize = 15)
plt.ylim([0,90])
plt.title("Adult Test Data Set Accuracy", fontsize = 15)
#plt.show()
plt.savefig('out/svmadult.jpg',bbox_inches='tight', dpi=150)

# %%
A = np.array([0.12,0.098,0.09])
B = np.array([0.15,0.153,0.09])

fig = plt.figure(figsize=(10,5))
#plt.xticks([0,1,2],["a","b","c"])
ax = fig.add_axes([0,0,1,1])
spaced = np.array([1,7,13])
ax.bar(spaced, A*100, color = 'navy', width = 2)
ax.bar(spaced+2, B*100, color='g',width=2)
#ax.set_xticks([0, 1, 2], ["Innter Product","Polynomial","Gaussian"])
plt.xticks([2,8,14],["Inner Product","Polynomial","Gaussian"], fontsize=12)
#ax.set_yticks(np.arange(75,85, 1))
ax.set_ylabel("Accuracy (%)", fontsize = 15)
ax.set_xlabel("Kernel", fontsize = 15)
ax.legend(['Simplified SMO','Extended SMO'], fontsize = 15)
plt.ylim([0,50])
plt.title("MNIST Test Data Set Accuracy", fontsize = 15)
#plt.show()
plt.savefig('out/svmmnist.jpg',bbox_inches='tight', dpi=150)
